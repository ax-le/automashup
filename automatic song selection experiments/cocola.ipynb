# %%
import os
import torch
import librosa
from itertools import product  # Pour générer toutes les paires possibles
from cocola.contrastive_model import constants
from cocola.contrastive_model.contrastive_model import CoCola
from cocola.feature_extraction.feature_extraction import CoColaFeatureExtractor
import sys
sys.path.append("./cocola")
import torchaudio
import torchaudio.transforms as T

# Dossier contenant les fichiers séparés (vocals, bass, drums, other)
htdemucs_folder = "./processed/separated/htdemucs"

# Charger le modèle pré-entraîné Cocola
# Charger le modèle pré-entraîné Cocola avec des entrées à 2 canaux
model = CoCola.load_from_checkpoint(
    "./cocola/checkpoint.ckpt", 
    input_type=constants.ModelInputType.DOUBLE_CHANNEL_HARMONIC_PERCUSSIVE
)

feature_extractor = CoColaFeatureExtractor()
model.eval()

# Définir le mode d'embedding
model.set_embedding_mode(constants.EmbeddingMode.BOTH)  # Ou HARMONIC/PERCUSSIVE selon besoin

# Stockage des features extraits pour éviter de les recalculer
vocals_features = {}
instrumentals_features = {}

# Fonction pour charger et prétraiter un fichier audio
def load_and_preprocess(file_path, target_sr=44100):
    print(f"📥 Chargement de {file_path}")  # Debug
    waveform, base_sr = torchaudio.load(file_path)

    # Resample à la fréquence cible si nécessaire
    if base_sr != target_sr:
        resampler = T.Resample(base_sr, target_sr)
        waveform = resampler(waveform)

    # Convertir en mono si nécessaire
    if waveform.shape[0] > 1:
        waveform = torch.mean(waveform, dim=0, keepdim=False)
    else:
        waveform = waveform.squeeze()

    # Tronquer à 10 secondes maximum (si nécessaire)
    #max_length = target_sr * 10  # 10 secondes
    #waveform = waveform[:max_length]

    # Ajouter une dimension de batch et une dimension de canal
    waveform = waveform.unsqueeze(0)  # (B, C, N)
    return waveform
# **Parcourir tous les dossiers des musiques pour extraire les embeddings**
for music_folder in os.listdir(htdemucs_folder):
    music_path = os.path.join(htdemucs_folder, music_folder)
    if not os.path.isdir(music_path):
        continue  # Ignorer les fichiers non pertinents

    print(f"\n🔹 Extraction des features pour : {music_folder}")

    vocals_path = os.path.join(music_path, "vocals.wav")
    bass_path = os.path.join(music_path, "bass.wav")
    drums_path = os.path.join(music_path, "drums.wav")
    other_path = os.path.join(music_path, "other.wav")

    # Charger et traiter les vocaux
    if os.path.exists(vocals_path):
        vocals_waveform = load_and_preprocess(vocals_path)
        vocals_features[music_folder] = feature_extractor(vocals_waveform)

    # Additionner les fichiers instrumentaux
    instrumental_waveform = None
    for inst_path in [bass_path, drums_path, other_path]:
        if os.path.exists(inst_path):
            waveform = load_and_preprocess(inst_path)
            instrumental_waveform = waveform if instrumental_waveform is None else instrumental_waveform[:waveform.shape[0]] + waveform[:instrumental_waveform.shape[0]]

    # Stocker les features des instrumentaux
    if instrumental_waveform is not None:
        instrumentals_features[music_folder] = feature_extractor(instrumental_waveform)
# Out:
# 🔹 Extraction des features pour : Bam Bam - Hi-Q
# 📥 Chargement de ./processed/separated/htdemucs\Bam Bam - Hi-Q\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\Bam Bam - Hi-Q\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\Bam Bam - Hi-Q\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\Bam Bam - Hi-Q\other.wav
#
# 🔹 Extraction des features pour : Benji Cossa - New Flowers (Fast 4-track Version)
# 📥 Chargement de ./processed/separated/htdemucs\Benji Cossa - New Flowers (Fast 4-track Version)\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\Benji Cossa - New Flowers (Fast 4-track Version)\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\Benji Cossa - New Flowers (Fast 4-track Version)\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\Benji Cossa - New Flowers (Fast 4-track Version)\other.wav
#
# 🔹 Extraction des features pour : Bessie Smith - My Sweetie Went Away
# 📥 Chargement de ./processed/separated/htdemucs\Bessie Smith - My Sweetie Went Away\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\Bessie Smith - My Sweetie Went Away\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\Bessie Smith - My Sweetie Went Away\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\Bessie Smith - My Sweetie Went Away\other.wav
#
# 🔹 Extraction des features pour : David Rovics - We Just Want The World
# 📥 Chargement de ./processed/separated/htdemucs\David Rovics - We Just Want The World\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\David Rovics - We Just Want The World\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\David Rovics - We Just Want The World\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\David Rovics - We Just Want The World\other.wav
#
# 🔹 Extraction des features pour : deef - Ein sonniger Tag mit dir
# 📥 Chargement de ./processed/separated/htdemucs\deef - Ein sonniger Tag mit dir\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\deef - Ein sonniger Tag mit dir\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\deef - Ein sonniger Tag mit dir\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\deef - Ein sonniger Tag mit dir\other.wav
#
# 🔹 Extraction des features pour : Dragon Or Emperor - Part of Me Says
# 📥 Chargement de ./processed/separated/htdemucs\Dragon Or Emperor - Part of Me Says\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\Dragon Or Emperor - Part of Me Says\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\Dragon Or Emperor - Part of Me Says\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\Dragon Or Emperor - Part of Me Says\other.wav
#
# 🔹 Extraction des features pour : Grand Mal - Children of Light
# 📥 Chargement de ./processed/separated/htdemucs\Grand Mal - Children of Light\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\Grand Mal - Children of Light\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\Grand Mal - Children of Light\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\Grand Mal - Children of Light\other.wav
#
# 🔹 Extraction des features pour : Home Blitz - Secret Wave
# 📥 Chargement de ./processed/separated/htdemucs\Home Blitz - Secret Wave\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\Home Blitz - Secret Wave\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\Home Blitz - Secret Wave\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\Home Blitz - Secret Wave\other.wav
#
# 🔹 Extraction des features pour : Josh Woodward - Cien Volando
# 📥 Chargement de ./processed/separated/htdemucs\Josh Woodward - Cien Volando\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\Josh Woodward - Cien Volando\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\Josh Woodward - Cien Volando\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\Josh Woodward - Cien Volando\other.wav
#
# 🔹 Extraction des features pour : Los Steaks - Sunday Girls
# 📥 Chargement de ./processed/separated/htdemucs\Los Steaks - Sunday Girls\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\Los Steaks - Sunday Girls\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\Los Steaks - Sunday Girls\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\Los Steaks - Sunday Girls\other.wav
#
# 🔹 Extraction des features pour : Mia Doi Todd - I gave you my home
# 📥 Chargement de ./processed/separated/htdemucs\Mia Doi Todd - I gave you my home\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\Mia Doi Todd - I gave you my home\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\Mia Doi Todd - I gave you my home\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\Mia Doi Todd - I gave you my home\other.wav
#
# 🔹 Extraction des features pour : Orange Peels - Grey Holiday
# 📥 Chargement de ./processed/separated/htdemucs\Orange Peels - Grey Holiday\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\Orange Peels - Grey Holiday\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\Orange Peels - Grey Holiday\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\Orange Peels - Grey Holiday\other.wav
#
# 🔹 Extraction des features pour : Poland - Lying Machine
# 📥 Chargement de ./processed/separated/htdemucs\Poland - Lying Machine\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\Poland - Lying Machine\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\Poland - Lying Machine\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\Poland - Lying Machine\other.wav
#
# 🔹 Extraction des features pour : Shearer - Itch
# 📥 Chargement de ./processed/separated/htdemucs\Shearer - Itch\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\Shearer - Itch\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\Shearer - Itch\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\Shearer - Itch\other.wav
#
# 🔹 Extraction des features pour : Short Hand - Certain Strangers
# 📥 Chargement de ./processed/separated/htdemucs\Short Hand - Certain Strangers\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\Short Hand - Certain Strangers\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\Short Hand - Certain Strangers\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\Short Hand - Certain Strangers\other.wav
#
# 🔹 Extraction des features pour : The Cute Lepers - Young Hearts
# 📥 Chargement de ./processed/separated/htdemucs\The Cute Lepers - Young Hearts\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\The Cute Lepers - Young Hearts\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\The Cute Lepers - Young Hearts\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\The Cute Lepers - Young Hearts\other.wav
#
# 🔹 Extraction des features pour : The Embarrassment - Patio Set
# 📥 Chargement de ./processed/separated/htdemucs\The Embarrassment - Patio Set\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\The Embarrassment - Patio Set\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\The Embarrassment - Patio Set\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\The Embarrassment - Patio Set\other.wav
#
# 🔹 Extraction des features pour : The J Arthur Keenes Band - The Boring World of Niels Bohr
# 📥 Chargement de ./processed/separated/htdemucs\The J Arthur Keenes Band - The Boring World of Niels Bohr\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\The J Arthur Keenes Band - The Boring World of Niels Bohr\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\The J Arthur Keenes Band - The Boring World of Niels Bohr\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\The J Arthur Keenes Band - The Boring World of Niels Bohr\other.wav
#
# 🔹 Extraction des features pour : The Oranges Band - Ride the Nuclear Wave
# 📥 Chargement de ./processed/separated/htdemucs\The Oranges Band - Ride the Nuclear Wave\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\The Oranges Band - Ride the Nuclear Wave\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\The Oranges Band - Ride the Nuclear Wave\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\The Oranges Band - Ride the Nuclear Wave\other.wav
#
# 🔹 Extraction des features pour : Wann - Happy Birthday
# 📥 Chargement de ./processed/separated/htdemucs\Wann - Happy Birthday\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\Wann - Happy Birthday\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\Wann - Happy Birthday\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\Wann - Happy Birthday\other.wav
#
# 🔹 Extraction des features pour : ZOELEELA - Jewel
# 📥 Chargement de ./processed/separated/htdemucs\ZOELEELA - Jewel\vocals.wav
# 📥 Chargement de ./processed/separated/htdemucs\ZOELEELA - Jewel\bass.wav
# 📥 Chargement de ./processed/separated/htdemucs\ZOELEELA - Jewel\drums.wav
# 📥 Chargement de ./processed/separated/htdemucs\ZOELEELA - Jewel\other.wav

# %%
save_path = "./features_cocola"
os.makedirs(save_path, exist_ok=True)
# Sauvegarder les features extraites
torch.save(vocals_features, os.path.join(save_path, "vocals_features.pt"))
torch.save(instrumentals_features, os.path.join(save_path, "instrumentals_features.pt"))
print("\n✅ Extraction des features terminée !")
# Out:
# ✅ Extraction des features terminée !
